# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("jobs.csv")

# %%
df
# Out:
#    Unnamed: 0  id  user_id                           title  \
# 0           0   1        5                        software
# 1           1   2        6        Public relations officer
# 2           2   3        6              software developer
# 3           3   4        6              accounting auditor
# 4           4   5        6              IT Project Manager
# 5           5   6        2            Enterprise AI Expert
# 6           6   7        5                  Land economist
# 7           7   8        5                   web developer
# 8           8   9        5  Revenue Reporting Data Analyst
#
#                                          description     location  job_type  \
# 0  <p>The Candidate must have skill in web develo...       Madina         2
# 1  <p>Public relations officer must be a person o...     Takoradi         3
# 2                    <p>fasjlsfljfsljksfjklafjkl</p>        accra         1
# 3                            <p>fasjhasfjkasjkjk</p>        accra         3
# 4  <p>Roles and Responsibilities</p>\r\n\r\n<ul>\...     dansoman         1
# 5  <p>Must be skilled in all aspect of AI from ma...        Kasoa         1
# 6  <p>lan afjkasdfjkldfasjkl sdfjklasdfl &nbsp;&n...  Cantonments         2
# 7  <p>We are looking for an outstanding Web Devel...         Tema         3
# 8  <p>Revenue Reporting Data Analyst, Business Fi...       Kumasi         2
#
#    category_id  salary       company_name  \
# 0            2     NaN  Korle Bu hospital
# 1            1     NaN     Zanku ventures
# 2            2     NaN     zanku ventures
# 3            1     NaN              zanku
# 4            2     NaN     zanku ventures
# 5            3    3000       Nestle Ghana
# 6            1    4000            ghtowns
# 7            3  Ghs500            ghTowns
# 8            1     NaN            ghTowns
#
#                                  company_description                     url  \
# 0  <p>Korle Bu is one of the oldest public health...  https://korlebu.com.gh
# 1  <p>Zanku ventures is the best when it comes to...       https://zanku.com
# 2          <p>afjklafsjklsdfjklsfdjklsjk&nbsp; f</p>       https://zanku.com
# 3                    <p>business is in our blood</p>      https://google.com
# 4    <p>The best Banking enterprise in the world</p>       https://zanku.com
# 5              <p>The best business in teh world</p>   https://nestle.com.gh
# 6                    <p>BEST REAL ESTATE COMPANY</p>     https://ghtowns.com
# 7  <p>The real Estate company in the Ghana. We be...     https://ghtowns.com
# 8  <p>The best real Estate business in the world</p>     https://ghtowns.com
#
#     last_date  is_published  is_closed                         timestamp
# 0  2022-07-20          True      False  2022-07-14 07:56:43.492471+00:00
# 1  2022-07-27          True      False  2022-07-14 07:55:42.270524+00:00
# 2  2022-07-31          True      False  2022-07-15 00:22:36.658060+00:00
# 3  2022-07-24          True      False  2022-07-15 00:22:27.038219+00:00
# 4  2022-07-19          True      False  2022-07-14 08:51:44.149594+00:00
# 5  2022-07-03          True      False  2022-07-16 10:59:34.291689+00:00
# 6  2022-07-16          True      False  2022-07-16 11:02:56.743717+00:00
# 7  2022-07-31          True      False  2022-07-20 13:37:15.194168+00:00
# 8  2022-08-05          True      False  2022-07-20 14:04:49.333926+00:00

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'user_id', 'title', 'description', 'location',
#        'job_type', 'category_id', 'salary', 'company_name',
#        'company_description', 'url', 'last_date', 'is_published', 'is_closed',
#        'timestamp'],
#       dtype='object')

# %%
from nltk.stem import PorterStemmer, WordNetLemmatizer
import re

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
# ----> 1 re.sub(r"[^\w\s]", " ", df['description'].str())
#
# TypeError: 'StringMethods' object is not callable
